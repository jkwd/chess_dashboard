# %%
import asyncio
import chess
import chess.engine
import time
import duckdb
import pandas as pd

# %%
db = duckdb.connect("chess.duckdb")
db.sql("SET TimeZone = 'UTC'")

# %%
db.sql("select * from information_schema.tables")
# Out:
# ┌───────────────┬─────────────────┬──────────────────────┬───┬──────────┬───────────────┬───────────────┐
# │ table_catalog │  table_schema   │      table_name      │ … │ is_typed │ commit_action │ TABLE_COMMENT │
# │    varchar    │     varchar     │       varchar        │   │ varchar  │    varchar    │    varchar    │
# ├───────────────┼─────────────────┼──────────────────────┼───┼──────────┼───────────────┼───────────────┤
# │ chess         │ chess_data_prep │ game_moves           │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_prep │ game_moves_centipawn │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_prep │ player_games         │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_prep │ player_game_moves    │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_raw  │ players_games        │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_raw  │ players_profiles     │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_raw  │ _dlt_loads           │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_raw  │ _dlt_pipeline_state  │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ chess_data_raw  │ _dlt_version         │ … │ NO       │ NULL          │ NULL          │
# │ chess         │ main            │ test                 │ … │ NO       │ NULL          │ NULL          │
# ├───────────────┴─────────────────┴──────────────────────┴───┴──────────┴───────────────┴───────────────┤
# │ 10 rows                                                                          13 columns (6 shown) │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
db.sql("select * from chess_data_prep.player_games where uuid = '0382938d-05f5-11ef-9338-b21a8d01000f' ").to_df()
# Out:
#   player_color  player_rating player_result  opponent_rating opponent_result  \
# 0        Black            599    checkmated              622             win
#
#    is_stronger_opponent player_wdl player_wdl_reason  eco game_start_date  \
# 0                  True       lose        checkmated  B53      2024-04-29
#
#    ...                                  white__aid white__username  \
# 0  ...  https://api.chess.com/pub/player/huyhayden       HuyHayden
#
#                             white__uuid black__rating  black__result  \
# 0  c507c630-42aa-11ee-808f-ddd1604df8bb           599     checkmated
#
#                                       black__aid black__username  \
# 0  https://api.chess.com/pub/player/johnnywhoopp    johnnywhoopp
#
#                             black__uuid accuracies__white  accuracies__black
# 0  a8d052da-f18b-11ee-b5a6-410d39dba314               NaN                NaN
#
# [1 rows x 38 columns]

# %%
q = """
with move as (
    select 
    uuid
    , game_move_index
    , game_move_fen 
    from chess_data_prep.game_moves 
    where uuid = '0382938d-05f5-11ef-9338-b21a8d01000f' 
    order by game_move_index
)
, player_color as (
    select
    uuid
    , player_color
    from chess_data_prep.player_games 
    where uuid = '0382938d-05f5-11ef-9338-b21a8d01000f'
)
select
player_color
, m.*
from move as m
left join player_color as pc
on m.uuid = pc.uuid
"""

# %%
async def process_fen(sample):
    player_color, uuid, move_index, fen = sample
    transport, engine = await chess.engine.popen_uci("/opt/homebrew/bin/stockfish")
    board = chess.Board(fen=fen)
    info = await engine.analyse(board, chess.engine.Limit(time=0.1))
    score = info["score"]
    # if player_color == 'White':
    #     score = score.white().score()
    # else:
    #     score = score.black().score()
    await engine.quit()
    return [uuid, move_index, score]

# %%
async def process_data():
    samples = db.sql(q).to_df().values.tolist()
    res = await asyncio.gather(*map(process_fen, samples))
    return res

# %%
res = await process_data()

# %%
pd.DataFrame(res, columns=['uuid', 'game_move_index', 'player_centipawn_score'])
# Out:
#                                     uuid  game_move_index  \
# 0   0382938d-05f5-11ef-9338-b21a8d01000f                1
# 1   0382938d-05f5-11ef-9338-b21a8d01000f                2
# 2   0382938d-05f5-11ef-9338-b21a8d01000f                3
# 3   0382938d-05f5-11ef-9338-b21a8d01000f                4
# 4   0382938d-05f5-11ef-9338-b21a8d01000f                5
# ..                                   ...              ...
# 82  0382938d-05f5-11ef-9338-b21a8d01000f               83
# 83  0382938d-05f5-11ef-9338-b21a8d01000f               84
# 84  0382938d-05f5-11ef-9338-b21a8d01000f               85
# 85  0382938d-05f5-11ef-9338-b21a8d01000f               86
# 86  0382938d-05f5-11ef-9338-b21a8d01000f               87
#
#         player_centipawn_score
# 0     PovScore(Cp(-36), BLACK)
# 1     PovScore(Cp(+35), WHITE)
# 2     PovScore(Cp(-26), BLACK)
# 3     PovScore(Cp(+31), WHITE)
# 4     PovScore(Cp(-33), BLACK)
# ..                         ...
# 82  PovScore(Mate(-15), BLACK)
# 83   PovScore(Mate(+2), WHITE)
# 84   PovScore(Mate(-1), BLACK)
# 85   PovScore(Mate(+1), WHITE)
# 86   PovScore(Mate(-0), BLACK)
#
# [87 rows x 3 columns]
